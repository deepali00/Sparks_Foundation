# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("datasets/task1.csv")

# %%
dataset.head()
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %%
dataset.plot(x='Hours',y='Scores')
plt.title('Hours vs Percentage')
plt.xlabel('Hours Studied')
plt.ylabel('Percentage')
plt.show()

# %%
x = dataset.iloc[:,:-1].values
y = dataset.iloc[:,1].values

# %%
x.shape
# Out:
# (25, 1)

# %%
y.shape
# Out:
# (25,)

# %%
from sklearn.model_selection import train_test_split
xtrain , xtest , ytrain , ytest = train_test_split(x ,y , test_size= 0.2 , random_state = 0)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit (xtrain,ytrain)
# Out:
# LinearRegression()

# %%
print(xtest)
# Out:
# [[1.5]
#  [3.2]
#  [7.4]
#  [2.5]
#  [5.9]]

# %%
predicted_value = model.predict(xtest)
print(predicted_value)
# Out:
# [16.88414476 33.73226078 75.357018   26.79480124 60.49103328]

# %%
from sklearn.metrics import accuracy_score

# %%
print(predicted_value.shape)
# Out:
# (5,)

# %%
ytest.shape
# Out:
# (5,)

# %%
data_for_accuracy = pd.DataFrame({'Actual': ytest, 'Predicted': predicted_value})

# %%
data_for_accuracy
# Out:
#    Actual  Predicted
# 0      20  16.884145
# 1      27  33.732261
# 2      69  75.357018
# 3      30  26.794801
# 4      62  60.491033

# %%
hours = [[9.25]]
own_prediction = model.predict(hours)
print("no of hours = {}".format(hours))
print("Prediction Score = {}".format(own_prediction[0]))
# Out:
# no of hours = [[9.25]]
# Prediction Score = 93.69173248737535
